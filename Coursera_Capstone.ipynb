# %% [markdown]
# # This notebook will be mainly used for the capstone project.

# %%
import pandas as pd
import numpy as np

# %%
print ("Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!

# %% [markdown]
# # Segmenting and Clustering Neighborhoods in Toronto

# %%
# initialize list of lists 
data = [['M1B', 'Scarborough','Malvern, Rouge',66108],
        ['M1C', 'Scarborough','Rouge Hill, Port Union, Highland Creek',35626],
        ['M1E', 'Scarborough','Guildwood, Morningside, West Hill',46943],
        ['M1G', 'Scarborough','Woburn',29690],
        ['M1H', 'Scarborough','Cedarbrae',24383],
        ['M1J', 'Scarborough','Scarborough Village',36699],
        ['M1K', 'Scarborough','Kennedy Park, Ionview, East Birchmount Park',48434],
        ['M1L', 'Scarborough','Golden Mile, Clairlea, Oakridge',35081],
        ['M1M', 'Scarborough','Cliffside, Cliffcrest, Scarborough Village West',22913],
        ['M1N', 'Scarborough','Birch Cliff, Cliffside West',22136],
        ['M1P', 'Scarborough','Dorset Park, Wexford Heights, Scarborough Town Centre',45571],
        ['M1R', 'Scarborough','Wexford, Maryvale',29858],
        ['M1S', 'Scarborough','Agincourt',37769],
        ['M1T', 'Scarborough','Clarks Corners, Tam O"Shanter, Sullivan',34588],
        ['M1V', 'Scarborough','Milliken, Agincourt North, Steeles East, L''Amoreux East',54680],
        ['M1W', 'Scarborough','Steeles West, L"Amoreaux West',48471],
        ['M1X', 'Scarborough','Upper Rouge',15097],
        ['M2H', 'North York','Hillcrest Village',24497],
        ['M2J', 'North York','Fairview, Henry Farm, Oriole',58293],
        ['M2K', 'North York','Bayview Village',23852],
        ['M2L', 'North York','York Mills, Silver Hills',11717],
        ['M2N', 'North York','Willowdale, Newtonbrook',32320],
        ['M2N', 'North York','Willowdale South',75897],
        ['M2P', 'North York','York Mills West',7843],
        ['M2R', 'North York','Willowdale West',40792],
        ['M3A', 'North York','Parkwoods',34615],
        ['M3B', 'North York','Don Mills North',13324],
        ['M3C', 'North York','Don Mills South, Flemingdon Park',39153],
        ['M3H', 'North York','Bathurst Manor, Wilson Heights, Downsview North',37011],
        ['M3J', 'North York','Northwood Park, York University',25473],
        ['M3K', 'North York','Downsview East, CFB Toronto',5997],
        ['M3L', 'North York','Downsview West',17339],
        ['M3M', 'North York','Downsview Central',24046],
        ['M3N', 'North York','Downsview Northeast',41958],
        ['M4A', 'North York','Victoria Village',14443],
        ['M4B', 'East York','Parkview Hill, Woodbine Gardens',18628],
        ['M4C', 'East York','Woodbine Heights',46866],
        ['M4E', 'East Toronto','The Beaches',25044],
        ['M4G', 'East York','Leaside',19076],
        ['M4H', 'East York','Thorncliffe Park',19688],
        ['M4J', 'East York','The Danforth East',35738],
        ['M4K', 'East Toronto','The Danforth West, Riverdale',31583],
        ['M4L', 'East Toronto','India Bazaar, The Beaches West',32640],
        ['M4M', 'Central Toronto','Studio District',24689],
        ['M4N', 'Central Toronto','Lawrence Park',15330],
        ['M4P', 'Central Toronto','Davisville North',20039],
        ['M4R', 'Central Toronto','North Toronto West',11394],
        ['M4S', 'Central Toronto','Davisville',26506],
        ['M4T', 'Central Toronto','Moore Park, Summerhill East',10463],
        ['M4V', 'Central Toronto','Summerhill West, Rathnelly, South Hill, Forest Hill SE, Deer Park',18241],
        ['M4W', 'Downtown Toronto','Rosedale',14561],
        ['M4X', 'Downtown Toronto','St. James Town, Cabbagetown',20822],
        ['M4Y', 'Downtown Toronto','Church and Wellesley',30472],
        ['M5A', 'Downtown Toronto','Regent Park, Harbourfront',41078],
        ['M5B', 'Downtown Toronto','Garden District, Ryerson',12785],
        ['M5C', 'Downtown Toronto','St. James Town',2951],
        ['M5E', 'Downtown Toronto','Berczy Park',9118],
        ['M5G', 'Downtown Toronto','Central Bay Street',8423],
        ['M5H', 'Downtown Toronto','Richmond, Adelaide, King',2005],
        ['M5J', 'Downtown Toronto','Harbourfront East, Union Station, Toronto Islands',14545],
        ['M5K', 'Downtown Toronto','Dominion Centre, Design Exchange',0],
        ['M5L', 'Downtown Toronto','Commerce Court, Victoria Hotel',0],
        ['M5M', 'North York','Bedford Park, Lawrence Manor East',25975],
        ['M5N', 'Central Toronto','Roselawn',16610],
        ['M5P', 'Central Toronto','Forest Hill North & West',19423],
        ['M5R', 'Central Toronto','The Annex, North Midtown, Yorkville',26496],
        ['M5S', 'Downtown Toronto','University of Toronto, Harbord',15372],
        ['M5T', 'Downtown Toronto','Kensington Market, Chinatown, Grange Park',17748],
        ['M5V', 'Downtown Toronto','CN Tower, King and Spadina, Railway Lands, Harbourfront West, Bathurst Quay, South Niagara, Island Airport',49195],
        ['M5W', 'Downtown Toronto','Stn A PO Boxes 25, The Esplanade',15],
        ['M5X', 'Downtown Toronto','First Canadian Place, Underground City',10],
        ['M6A', 'North York','Lawrence Manor, Lawrence Heights',21048],
        ['M6B', 'North York','Glencairn',28522],
        ['M6C', 'York','Humewood-Cedarvale',24596],
        ['M6E', 'York','Caledonia-Fairbanks',38041],
        ['M6G', 'Downtown Toronto','Christie',32086],
        ['M6H', 'West Toronto','Dufferin, Dovercourt Village',44950],
        ['M6J', 'West Toronto','Little Portugal, Trinity',32684],
        ['M6K', 'West Toronto','Brockton, Parkdale Village, Exhibition Place',40957],
        ['M6L', 'North York','North Park, Maple Leaf Park, Upwood Park',20616],
        ['M6M', 'York','Del Ray, Mount Dennis, Keelsdale and Silverthorn',42434],
        ['M6N', 'York','Runnymede, The Junction North',41243],
        ['M6P', 'West Toronto','High Park, The Junction South',40035],
        ['M6R', 'West Toronto','Parkdale, Roncesvalles',19857],
        ['M6S', 'West Toronto','Runnymede, Swansea',34299],
        ['M7A', 'Queen''s Park', 'Ontario Provincial Government',10],
        ['M7R', 'Mississauga', 'Canada Post Gateway Processing Centre',0],
        ['M7Y', 'East Toronto', 'Business Reply Mail Processing Centre, 969 Eastern',10],
        ['M8V', 'Etobicoke', 'New Toronto, Mimico South, Humber Bay Shores',37975],
        ['M8W', 'Etobicoke', 'Alderwood, Long Branch',20674],
        ['M8X', 'Etobicoke', 'The Kingsway, Montgomery Road, Old Mill North',10787],
        ['M8Y', 'Etobicoke', 'Old Mill South, King''s Mill Park, Sunnylea, Humber Bay, Mimico NE, The Queensway East, Royal York South East, Kingsway Park South East',21299],
        ['M8Z', 'Etobicoke', 'Mimico NW, The Queensway West, South of Bloor, Kingsway Park South West, Royal York South West',17038],
        ['M9A', 'Etobicoke', 'Islington Avenue',35594],
        ['M9B', 'Etobicoke', 'West Deane Park, Princess Gardens, Martin Grove, Islington, Cloverdale',32400],
        ['M9C', 'Etobicoke', 'Eringate, Bloordale Gardens, Old Burnhamthorpe, Markland Wood',38291],
        ['M9L', 'North York', 'Humber Summit',11950],
        ['M9M', 'North York', 'Humberlea, Emery',22263],
        ['M9N', 'York', 'Weston',25074],
        ['M9P', 'Etobicoke', 'Westmount',20874],
        ['M9R', 'Etobicoke', 'Kingsview Village, St. Phillips, Martin Grove Gardens, Richview Gardens',33743],
        ['M9V', 'Etobicoke', 'South Steeles, Silverstone, Humbergate, Jamestown, Mount Olive, Beaumond Heights, Thistletown, Albion Gardens',55959],
        ['M9W', 'Etobicoke Northwest', 'Clairville, Humberwood, Woodbine Downs, West Humber, Kipling Heights, Rexdale, Elms, Tandridge, Old Rexdale',40684],
       ] 
  
# Create the pandas DataFrame 
df = pd.DataFrame(data, columns = ['Postal Code', 'Borough', 'Neighborhood', 'Total Population']) 
  
# print dataframe. 
df
# Out:
#     Postal Code              Borough  \
# 0           M1B          Scarborough
# 1           M1C          Scarborough
# 2           M1E          Scarborough
# 3           M1G          Scarborough
# 4           M1H          Scarborough
# 5           M1J          Scarborough
# 6           M1K          Scarborough
# 7           M1L          Scarborough
# 8           M1M          Scarborough
# 9           M1N          Scarborough
# 10          M1P          Scarborough
# 11          M1R          Scarborough
# 12          M1S          Scarborough
# 13          M1T          Scarborough
# 14          M1V          Scarborough
# 15          M1W          Scarborough
# 16          M1X          Scarborough
# 17          M2H           North York
# 18          M2J           North York
# 19          M2K           North York
# 20          M2L           North York
# 21          M2N           North York
# 22          M2N           North York
# 23          M2P           North York
# ...

# %%
df.shape
# Out:
# (103, 4)

# %%
import types
import pandas as pd
from botocore.client import Config
import ibm_boto3

def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.
client_7d952261e08349698fcf886e241de0f1 = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='V7eu8owrIhkcY5yu2zLF4khAqYqU1mylZzVjxklykgZm',
    ibm_auth_endpoint="https://iam.ng.bluemix.net/oidc/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3-api.us-geo.objectstorage.service.networklayer.com')

body = client_7d952261e08349698fcf886e241de0f1.get_object(Bucket='courseracapstone-donotdelete-pr-m2s5h0cgwrfy3b',Key='Geospatial_Coordinates.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df1 = pd.read_csv(body)
df1.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
df2 = pd.concat([df, df1], axis = 1, sort = 'False')
df2
# Out:
#     Postal Code              Borough  \
# 0           M1B          Scarborough
# 1           M1C          Scarborough
# 2           M1E          Scarborough
# 3           M1G          Scarborough
# 4           M1H          Scarborough
# 5           M1J          Scarborough
# 6           M1K          Scarborough
# 7           M1L          Scarborough
# 8           M1M          Scarborough
# 9           M1N          Scarborough
# 10          M1P          Scarborough
# 11          M1R          Scarborough
# 12          M1S          Scarborough
# 13          M1T          Scarborough
# 14          M1V          Scarborough
# 15          M1W          Scarborough
# 16          M1X          Scarborough
# 17          M2H           North York
# 18          M2J           North York
# 19          M2K           North York
# 20          M2L           North York
# 21          M2N           North York
# 22          M2N           North York
# 23          M2P           North York
# ...

# %%
df2 = df2.loc[:,~df2.columns.duplicated()]

# %%
df2 = df2.sort_values(['Borough'], ascending=True)

# %% [markdown]
# #### Boroughs were sorted alphabetically

# %%
df2
# Out:
#    Postal Code           Borough  \
# 47         M4S   Central Toronto
# 63         M5N   Central Toronto
# 46         M4R   Central Toronto
# 65         M5R   Central Toronto
# 49         M4V   Central Toronto
# 64         M5P   Central Toronto
# 43         M4M   Central Toronto
# 44         M4N   Central Toronto
# 45         M4P   Central Toronto
# 48         M4T   Central Toronto
# 50         M4W  Downtown Toronto
# 52         M4Y  Downtown Toronto
# 53         M5A  Downtown Toronto
# 55         M5C  Downtown Toronto
# 56         M5E  Downtown Toronto
# 57         M5G  Downtown Toronto
# 58         M5H  Downtown Toronto
# 60         M5K  Downtown Toronto
# 61         M5L  Downtown Toronto
# 54         M5B  Downtown Toronto
# 51         M4X  Downtown Toronto
# 67         M5T  Downtown Toronto
# 66         M5S  Downtown Toronto
# 75         M6G  Downtown Toronto
# 59         M5J  Downtown Toronto
# 69         M5W  Downtown Toronto
# 70         M5X  Downtown Toronto
# ...

# %% [markdown]
# ### Visualize Toronto neighborhoods

# %%
# !pip install folium
import folium
from folium.features import DivIcon

# %%
m = folium.Map(location = [43.7181557,-79.3732615], zoom_start = 11)

# %%
# I can add marker one by one on the map
for i in range(0,len(df2)):
    folium.Marker([df2.iloc[i]['Latitude'], df2.iloc[i]['Longitude']], popup=df2.iloc[i]['Postal Code']).add_to(m)
 
# Save it as html
m.save('toronto.html')

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Import necessary libraries

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# %%
# !conda install -c conda-forge geopy=1.19.0 --yes

# %%
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# %%
# !conda install -c conda-forge --no-deps altair --yes

# !conda install -c conda-forge --no-deps vincent --yes

# !conda install -c conda-forge --no-deps folium=0.5.0 --yes

# %%
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Folium installed
# Libraries imported.

# %% [markdown]
# ### FourSquare credentials

# %%
CLIENT_ID = 'YHZ2SUUOGKUROKZXE2DSKUXLS3U31VMFNNVTGFCEPUXQ0LHG' # your Foursquare ID
CLIENT_SECRET = 'FDBSEB0FUS2TXLGUUI1EKAEJL0NKSXZ14WM4JJ1FPLH55DZW' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 20
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: YHZ2SUUOGKUROKZXE2DSKUXLS3U31VMFNNVTGFCEPUXQ0LHG
# CLIENT_SECRET:FDBSEB0FUS2TXLGUUI1EKAEJL0NKSXZ14WM4JJ1FPLH55DZW

# %% [markdown]
# ### Toronto coordinates

# %%
address = 'Toronto, ON, Canada'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 43.653963 -79.387207

# %% [markdown]
# ### Search for universities

# %%
search_query = 'University'
radius = 20000
print(search_query + ' .... OK!')
# Out:
# University .... OK!

# %% [markdown]
# ### Define corresponding URL

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=YHZ2SUUOGKUROKZXE2DSKUXLS3U31VMFNNVTGFCEPUXQ0LHG&client_secret=FDBSEB0FUS2TXLGUUI1EKAEJL0NKSXZ14WM4JJ1FPLH55DZW&ll=43.653963,-79.387207&v=20180604&query=University&radius=20000&limit=20'

# %% [markdown]
# ### Send the GET request and examine results

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5e7b2c0e0be7b4001c81ea19'},
#  'response': {'venues': [{'id': '4ad4c05ef964a52097f620e3',
#     'name': 'University of Toronto',
#     'location': {'address': "27 King's College Cir",
#      'crossStreet': "at King's College Rd",
#      'lat': 43.6624934706167,
#      'lng': -79.39521976633822,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.6624934706167,
#        'lng': -79.39521976633822}],
#      'distance': 1148,
#      'postalCode': 'M5S 1A1',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ["27 King's College Cir (at King's College Rd)",
#       'Toronto ON M5S 1A1',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ae941735',
#       'name': 'University',
#       'pluralName': 'Universities',
#       'shortName': 'University',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/default_',
# ...

# %% [markdown]
# ### Get relevant parts of JSON and transform to pandas dataframe

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1ae941735', 'name': 'U...    False
# 1  [{'id': '4bf58dd8d48988d124941735', 'name': 'O...    False
# 2  [{'id': '4bf58dd8d48988d124941735', 'name': 'O...    False
# 3  [{'id': '4bf58dd8d48988d175941735', 'name': 'G...    False
# 4  [{'id': '4bf58dd8d48988d104941735', 'name': 'M...    False
#
#                          id           location.address location.cc  \
# 0  4ad4c05ef964a52097f620e3      27 King's College Cir          CA
# 1  4b13d2cff964a5207f9923e3         480 University Ave          CA
# 2  4c45c6c6da2176b09543637a        393 University Ave.          CA
# 3  4cd044c29d87224bf129543b                        NaN          CA
# 4  4c6062b612e5c9286e131f4c  104-438 University Avenue          CA
#
#   location.city location.country  location.crossStreet  location.distance  \
# 0       Toronto           Canada  at King's College Rd               1148
# ...

# %% [markdown]
# ### Define information of interest and filter dataframe

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                                  name            categories  \
# 0                               University of Toronto            University
# 1                                  480 University Ave                Office
# 2                                   University Centre                Office
# 3                               University Centre Gym  Gym / Fitness Center
# 4                     Dundas University Health Clinic        Medical Center
# 5                                  438 University Ave                Office
# 6                             University Avenue Plaza                 Plaza
# 7   Ontario College of Art and Design University (...            University
# 8                                  393 University Ave                Office
# 9                                  Queen & University          Intersection
# 10                                  King & University                  Road
# ...

# %%
dataframe_filtered = dataframe_filtered.drop([dataframe_filtered.index[1] , dataframe_filtered.index[2],
                                             dataframe_filtered.index[3] , dataframe_filtered.index[4],
                                             dataframe_filtered.index[5] , dataframe_filtered.index[6],
                                             dataframe_filtered.index[7] , dataframe_filtered.index[8],
                                             dataframe_filtered.index[9] , dataframe_filtered.index[10],
                                             dataframe_filtered.index[11] , dataframe_filtered.index[12],
                                             dataframe_filtered.index[13] , dataframe_filtered.index[15],
                                             dataframe_filtered.index[16] , dataframe_filtered.index[17],
                                             dataframe_filtered.index[18] , dataframe_filtered.index[19]])
dataframe_filtered
# Out:
#                      name  categories                address  cc     city  \
# 0   University of Toronto  University  27 King's College Cir  CA  Toronto
# 14     Ryerson University  University       350 Victoria St.  CA  Toronto
#
#    country           crossStreet  distance  \
# 0   Canada  at King's College Rd      1148
# 14  Canada          at Gould St.       698
#
#                                      formattedAddress  \
# 0   [27 King's College Cir (at King's College Rd),...
# 14  [350 Victoria St. (at Gould St.), Toronto ON M...
#
#                                        labeledLatLngs        lat       lng  \
# 0   [{'label': 'display', 'lat': 43.6624934706167,...  43.662493 -79.39522
# 14  [{'label': 'display', 'lat': 43.65793504826254...  43.657935 -79.38049
#
#    neighborhood postalCode state                        id
# 0           NaN    M5S 1A1    ON  4ad4c05ef964a52097f620e3
# 14          NaN    M5B 2K3    ON  4ad7797cf964a520170b21e3

# %% [markdown]
# # York University search

# %%
search_query = 'York University'
radius = 20000
print(search_query + ' .... OK!')
# Out:
# York University .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=YHZ2SUUOGKUROKZXE2DSKUXLS3U31VMFNNVTGFCEPUXQ0LHG&client_secret=FDBSEB0FUS2TXLGUUI1EKAEJL0NKSXZ14WM4JJ1FPLH55DZW&ll=43.653963,-79.387207&v=20180604&query=York University&radius=20000&limit=20'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5e7b2bef60ba08001bbed5cd'},
#  'response': {'venues': [{'id': '4ad78121f964a5208b0b21e3',
#     'name': 'York University - Keele Campus',
#     'location': {'address': '4700 Keele St.',
#      'lat': 43.77210701043441,
#      'lng': -79.50218997939596,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.77210701043441,
#        'lng': -79.50218997939596}],
#      'distance': 16079,
#      'postalCode': 'M3J 1P3',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['4700 Keele St.', 'Toronto ON M3J 1P3', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ae941735',
#       'name': 'University',
#       'pluralName': 'Universities',
#       'shortName': 'University',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '42701099'},
# ...

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
york = json_normalize(venues)
york.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1ae941735', 'name': 'U...    False
# 1  [{'id': '4bf58dd8d48988d1a8941735', 'name': 'G...    False
# 2  [{'id': '4bf58dd8d48988d1fd931735', 'name': 'M...    False
# 3  [{'id': '4bf58dd8d48988d198941735', 'name': 'C...    False
# 4  [{'id': '4bf58dd8d48988d1ab941735', 'name': 'S...    False
#
#                          id          location.address location.cc  \
# 0  4ad78121f964a5208b0b21e3            4700 Keele St.          CA
# 1  5ae8647a0dd31f002e8af931                       NaN          CA
# 2  59299e2fda2e0026b11b8e7b    120 Ian Macdonald Blvd          CA
# 3  4b575a2ff964a520073328e3            4700 Keele St.          CA
# 4  4ae33cf1f964a5201d9221e3  4700 Keele St, Suite 335          CA
#
#   location.city location.country       location.crossStreet  \
# 0       Toronto           Canada                        NaN
# 1       Toronto           Canada                        NaN
# ...

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in york.columns if col.startswith('location.')] + ['id']
york = york.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
york['categories'] = york.apply(get_category_type, axis=1)

# clean column names by keeping only last term
york.columns = [column.split('.')[-1] for column in york.columns]

york
# Out:
#                                                  name  \
# 0                      York University - Keele Campus
# 1         York University  - Schullch Business School
# 2                      York University Subway Station
# 3               Curtis Lecture Hall - York University
# 4                      York University Student Centre
# 5                      York University, Ross Building
# 6                    York University, Parking Tickets
# 7                         York University Curtis Hall
# 8              Stedman Lecture Halls, York University
# 9             York University, Accolade West Building
# 10                     York University Student Centre
# 11                        TTC 106 York University Bus
# 12                    Scott Library - York University
# 13             Tait McKenzie Centre - York University
# 14                McLaughlin College, York University
# 15                         York University GO Station
# ...

# %%
york = york.drop([york.index[1] , york.index[2],
                                             york.index[3] , york.index[4],
                                             york.index[5] , york.index[6],
                                             york.index[7] , york.index[8],
                                             york.index[9] , york.index[10],
                                             york.index[11] , york.index[12],
                                             york.index[13] ,  york.index[14], york.index[15],
                                             york.index[16] , york.index[17],
                                             york.index[18] , york.index[19]])
york
# Out:
#                              name  categories         address  cc     city  \
# 0  York University - Keele Campus  University  4700 Keele St.  CA  Toronto
#
#   country crossStreet  distance                              formattedAddress  \
# 0  Canada         NaN     16079  [4700 Keele St., Toronto ON M3J 1P3, Canada]
#
#                                       labeledLatLngs        lat       lng  \
# 0  [{'label': 'display', 'lat': 43.77210701043441...  43.772107 -79.50219
#
#   neighborhood postalCode state                        id
# 0          NaN    M3J 1P3    ON  4ad78121f964a5208b0b21e3

# %% [markdown]
# ## Merge the two university dataframes

# %%
uni = dataframe_filtered.append(york)
uni
# Out:
#                               name  categories                address  cc  \
# 0            University of Toronto  University  27 King's College Cir  CA
# 14              Ryerson University  University       350 Victoria St.  CA
# 0   York University - Keele Campus  University         4700 Keele St.  CA
#
#        city country           crossStreet  distance  \
# 0   Toronto  Canada  at King's College Rd      1148
# 14  Toronto  Canada          at Gould St.       698
# 0   Toronto  Canada                   NaN     16079
#
#                                      formattedAddress  \
# 0   [27 King's College Cir (at King's College Rd),...
# 14  [350 Victoria St. (at Gould St.), Toronto ON M...
# 0        [4700 Keele St., Toronto ON M3J 1P3, Canada]
#
#                                        labeledLatLngs        lat       lng  \
# 0   [{'label': 'display', 'lat': 43.6624934706167,...  43.662493 -79.39522
# 14  [{'label': 'display', 'lat': 43.65793504826254...  43.657935 -79.38049
# ...

# %% [markdown]
# ### Visualize universities nearby

# %%
uni_map = folium.Map(location=[latitude, longitude], zoom_start=15) # generate map centred around Ecco
uni.name
# Out:
# 0              University of Toronto
# 14                Ryerson University
# 0     York University - Keele Campus
# Name: name, dtype: object

# %%
uni_map = folium.Map(location=[latitude, longitude], zoom_start=10) # generate map centred around Toronto

# add a red circle marker to represent Toronto
folium.Marker(
    [latitude, longitude],
    icon = folium.Icon(color='red'),
    color='red',
    popup='Toronto',
).add_to(uni_map)

# add the universities as blue circle markers
for lat, lng, label in zip(uni.lat, uni.lng, uni.categories):
    folium.Marker(
        [lat, lng],
        icon = folium.Icon(color='green'),
        popup=label,
    ).add_to(uni_map)

# display map
uni_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Create a choropleth map of Toronto postal codes with respect to population

# %%
import pandas as pd
import json
from folium import GeoJson 
import plotly.plotly as py
import sys
sys.path.append('..')
import folium
print (folium.__file__)
print (folium.__version__)
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/folium/__init__.py
# 0.10.1

# %%
from urllib.request import urlopen
import json
with urlopen('https://raw.githubusercontent.com/timcayanga/Coursera_Capstone/master/TorontoFSAs.geojson') as response:
    fsa = json.load(response)

fsa["features"][0]
# Out:
# {'type': 'Feature',
#  'properties': {'CFSAUID': 'M9R', 'PRUID': '35', 'PRNAME': 'Ontario'},
#  'geometry': {'type': 'MultiPolygon',
#   'coordinates': [[[[-79.5613053165675, 43.674784800510714],
#      [-79.56248600330755, 43.67458759097538],
#      [-79.56258440456196, 43.67462479033493],
#      [-79.56319650228333, 43.67454019854221],
#      [-79.56538430752339, 43.67431338986235],
#      [-79.5668485183485, 43.67421159572012],
#      [-79.56699098708835, 43.674206590024795],
#      [-79.56712701459196, 43.67419749574593],
#      [-79.56726348761242, 43.67419289124548],
#      [-79.56739951496259, 43.67418379653579],
#      [-79.56753548431061, 43.67418380255751],
#      [-79.56767188939811, 43.67417918777795],
#      [-79.56775419951764, 43.67417110668314],
#      [-79.56776878595709, 43.674169699833705],
#      [-79.56781029351805, 43.67416559418064],
#      [-79.56794739481535, 43.67415199433343],
#      [-79.56808459786872, 43.67413840874554],
# ...

# %%
# we can immediately drop the columns we're not interested in 
df_pop=df2[['Postal Code','Neighborhood', 'Total Population']]
df_pop.head()
# Out:
#    Postal Code                                       Neighborhood  \
# 47         M4S                                         Davisville
# 63         M5N                                           Roselawn
# 46         M4R                                 North Toronto West
# 65         M5R                The Annex, North Midtown, Yorkville
# 49         M4V  Summerhill West, Rathnelly, South Hill, Forest...
#
#     Total Population
# 47             26506
# 63             16610
# 46             11394
# 65             26496
# 49             18241

# %%
geo_json_data = fsa
df_pop = df_pop.set_index('Postal Code')['Total Population']

# %%
get_ipython().magic(u'matplotlib inline')

# %%
# create map of Toronto Neighbourhoods (FSAs) using retrived latitude and longitude values
TO = folium.Map(location=[43.653963, -79.387207], zoom_start=10)
ontario_geo = geo_json_data

# %%
TO.choropleth(geo_data=ontario_geo,
    data = df_pop,
    columns=['Postal Code','Total Population'],
    key_on='feature.properties.CFSAUID',
    fill_color='YlOrRd',
    fill_opacity=0.7, 
    line_opacity=0.2,
    text=["Postal Code", "Total Population"],
    legend_name='Population')

TO
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/folium/folium.py:415: FutureWarning:
#
# The choropleth  method has been deprecated. Instead use the new Choropleth class, which has the same arguments. See the example notebook 'GeoJSON_and_choropleth' for how to do this.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Add universities to choropleth map

# %%
# add the universities as blue circle markers
for lat, lng, label in zip(uni.lat, uni.lng, uni.name):
    folium.Marker(
        [lat, lng],
        icon = folium.Icon(color='green'),
        popup=label,
    ).add_to(TO)
    
TO
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Create a 3D scatter plot with respect to Latitude, Longitude, and Population

# %%
df3 = df2[['Longitude', 'Latitude', 'Total Population']].copy()
df3.head()
# Out:
#     Longitude   Latitude  Total Population
# 47 -79.388790  43.704324             26506
# 63 -79.416936  43.711695             16610
# 46 -79.405678  43.715383             11394
# 65 -79.405678  43.672710             26496
# 49 -79.400049  43.686412             18241

# %%
# %matplotlib notebook

from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt



fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

x =df2["Longitude"]
y =df2["Latitude"]
z =df2["Total Population"]



ax.scatter(x, y, z, c='r', marker='o')

ax.set_xlabel('Longitude')
ax.set_ylabel('Latitude')
ax.set_zlabel('Total Population')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %% [markdown]
# ## Cluster the 3D points

# %%
from sklearn.cluster import AgglomerativeClustering

cluster = AgglomerativeClustering(n_clusters=7, affinity='euclidean', linkage='ward')
KF = cluster.fit_predict(df3)
KF
# Out:
# array([0, 0, 3, 0, 0, 0, 0, 3, 0, 3, 3, 6, 2, 4, 3, 3, 4, 4, 4, 3, 0, 0,
#        3, 6, 3, 4, 4, 1, 4, 6, 6, 0, 2, 0, 0, 1, 0, 2, 0, 1, 0, 3, 0, 2,
#        2, 0, 2, 6, 2, 4, 2, 0, 3, 0, 0, 0, 1, 0, 3, 0, 6, 6, 3, 2, 2, 3,
#        2, 2, 0, 3, 0, 0, 5, 3, 4, 6, 2, 1, 2, 1, 0, 0, 1, 6, 0, 2, 2, 2,
#        1, 1, 3, 5, 0, 2, 2, 6, 1, 2, 2, 2, 2, 0, 0])

# %%
from sklearn.cluster import KMeans

# Initializing KMeans
kmeans = KMeans(n_clusters=7)
# Fitting with inputs
kmeans = kmeans.fit(df3)
# Predicting the clusters
labels = kmeans.predict(df3)
# Getting the cluster centers
C = kmeans.cluster_centers_

# %%
C
# Out:
# array([[-7.94070139e+01,  4.36591789e+01,  1.09980000e+03],
#        [-7.94395725e+01,  4.36996555e+01,  3.99418750e+04],
#        [-7.94062213e+01,  4.37032846e+01,  2.22750345e+04],
#        [-7.93305347e+01,  4.37451015e+01,  5.04902222e+04],
#        [-7.93779359e+01,  4.37070413e+01,  3.28632778e+04],
#        [-7.94022384e+01,  4.37044003e+01,  1.30599474e+04],
#        [-7.93014231e+01,  4.37884031e+01,  7.10025000e+04]])

# %%
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(df3['Longitude'], df3['Latitude'], df3['Total Population'], c=KF)
ax.scatter(C[:, 0], C[:, 1], C[:, 2], marker='.', c='red', s=1000)

ax.set_title('Clusters', fontsize= 30, alpha=0.6)
ax.set_xlabel('Longitude', fontsize= 20, alpha=0.6)
ax.set_ylabel('Latitude', fontsize= 20, alpha=0.6)
ax.set_zlabel('Total Population', fontsize= 20, alpha=0.6)
# Out:
# <img src="data:image/png;base64,..." width="432">
# Text(0.5, 0, 'Total Population')

# %%
df2.head(60)
# Out:
#     Postal Code              Borough  \
# 47          M4S      Central Toronto
# 63          M5N      Central Toronto
# 46          M4R      Central Toronto
# 65          M5R      Central Toronto
# 49          M4V      Central Toronto
# 64          M5P      Central Toronto
# 43          M4M      Central Toronto
# 44          M4N      Central Toronto
# 45          M4P      Central Toronto
# 48          M4T      Central Toronto
# 50          M4W     Downtown Toronto
# 52          M4Y     Downtown Toronto
# 53          M5A     Downtown Toronto
# 55          M5C     Downtown Toronto
# 56          M5E     Downtown Toronto
# 57          M5G     Downtown Toronto
# 58          M5H     Downtown Toronto
# 60          M5K     Downtown Toronto
# 61          M5L     Downtown Toronto
# 54          M5B     Downtown Toronto
# 51          M4X     Downtown Toronto
# 67          M5T     Downtown Toronto
# 66          M5S     Downtown Toronto
# 75          M6G     Downtown Toronto
# ...

# %%
df2.tail(43)
# Out:
#    Postal Code       Borough  \
# 72         M6B    North York
# 21         M2N    North York
# 23         M2P    North York
# 24         M2R    North York
# 25         M3A    North York
# 26         M3B    North York
# 27         M3C    North York
# 28         M3H    North York
# 29         M3J    North York
# 30         M3K    North York
# 31         M3L    North York
# 32         M3M    North York
# 22         M2N    North York
# 34         M4A    North York
# 85         M7A   Queens Park
# 3          M1G   Scarborough
# 5          M1J   Scarborough
# 6          M1K   Scarborough
# 7          M1L   Scarborough
# 2          M1E   Scarborough
# 8          M1M   Scarborough
# 9          M1N   Scarborough
# 10         M1P   Scarborough
# 11         M1R   Scarborough
# 4          M1H   Scarborough
# 1          M1C   Scarborough
# 12         M1S   Scarborough
# 13         M1T   Scarborough
# 14         M1V   Scarborough
# 15         M1W   Scarborough
# 16         M1X   Scarborough
# ...
